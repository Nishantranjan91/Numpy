# %%
a = 12
b = 15
print(a+b)
# Out:
# 27

# %%
import numpy as np
arr = np.array([10,20,30,40,50])
print(arr)
print(type(arr))
# Out:
# [10 20 30 40 50]
# <class 'numpy.ndarray'>

# %%
a = 12

# %%
b = 15

# %%
print(a+b)
# Out:
# 27

# %%
print()
